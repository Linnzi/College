# %% [markdown]
# ![Yurkin 4.1.png](attachment:image.png)

# %%
C = [12, -5, 0, 8, -3, -10, 7, 1, 38, -83]

neg_count = len([x for x in C if x < 0])
pos_sum = sum([x for x in C if x > 0])

print(f"Количество отрицательных: {neg_count}, Сумма положительных: {pos_sum}")
# Out:
# Количество отрицательных: 4, Сумма положительных: 66
